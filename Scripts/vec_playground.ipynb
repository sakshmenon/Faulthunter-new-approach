# %%
import platform
import os
import numpy as np
import tensorflow as tf
gpu_token = tf.test.is_gpu_available('GPU')

if platform.machine() == 'x86_64':
    if gpu_token:
        os.chdir('/home/ucdasec/Faulthunter-RNN-approach')
    else:
        os.chdir("/home/sakshmeno/Documents/GitHub/C-RNN-approach")
elif platform.machine() == 'arm64':
    os.chdir("/Users/saksh.menon/Documents/GitHub/C-RNN-approach")

from Utils.dataframe_gen import *
# from Utils.OneHot_gen import *
# from Utils.TFIDF_gen import *
# from Utils.word2vec_gen import *
from Utils.vector_gen import *
from Utils.w2b_encoding_lw_iter2 import *
# from Utils.word2vec_ver2 import *
# from Utils.w2b_encoding_lw import *
# Out:
# WARNING:tensorflow:From /var/folders/tl/9c2d6y_57n90z4swq88_fh7r0000gn/T/ipykernel_49592/333705433.py:5: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2024-04-28 23:21:11.803658: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-04-28 23:21:11.803675: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-04-28 23:21:11.803681: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-04-28 23:21:11.803709: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
original_df, _, DEF_DICT, DEC_DICT  = dataframe_init(gpu_token)
vectors = vec_split(original_df)
vectors = encoder2(vectors, DEF_DICT, DEC_DICT)
# Out:
# /Users/saksh.menon/Documents/GitHub/C-RNN-approach/Utils/w2b_encoding_lw_iter2.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vectors[vector]['Encoded Lines'][row[0]] = [eval(i) for i in encodedline]#tuple(encodedline)
# /Users/saksh.menon/Documents/GitHub/C-RNN-approach/Utils/w2b_encoding_lw_iter2.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vectors[vector]['Encoded Lines'][row[0]] = [eval(i) for i in encodedline]#tuple(encodedline)
# /Users/saksh.menon/Documents/GitHub/C-RNN-approach/Utils/w2b_encoding_lw_iter2.py:127: SettingWithCopyWarning:
# ...

# %%
DEC_DICT
# Out:
# {'AX3_Firmware main.c': [['int INTCON1val'],
#   ['int i'],
#   ['int i'],
#   ['int i'],
#   ['int LEDTimer'],
#   ['int i'],
#   ['int failCounter']],
#  'ESP8266-Firmware main.c': [['int magic'],
#   ['int resetCounter'],
#   ['int mSpecialMode'],
#   ['int f'],
#   ['int ever_saved']],
#  'Firmament-Autopilot i2c_core.c': [],
#  'Hardware-Bitcoin-Wallet xex.c': [['int test_number'],
#   ['int data_unit_length'],
#   ['bool is_encrypt'],
#   ['int i'],
#   ['int j'],
#   ['int value'],
#   ['bool seen_count'],
#   ['bool test_failed'],
#   ['int n'],
#   ['int i'],
#   ['int j']],
#  'iotkit-embedded iotx_http_api.c': [['int     rc'],
#   ['int                 ret'],
#   ['int                 ret_code'],
#   ['int                 len'],
#   ['int                 ret'],
#   ['int                 response_code'],
#   ['int                 len']],
#  'm2_fingerprint main.c': [['int fingerprintID']],
#  'mbd-arduino-cashless mdb.c': [],
# ...

# %%
original_df[original_df['Label']==1].to_excel('insecure stuff.xlsx')

# %%
drop_list = [490,624,876,1226,2033,2037,2199,4165,4240,4242,4244,4248,4250,4530,4608,4656]
for i in drop_list:
    original_df.drop(index=i,inplace = True)

# %%
vectors[0].to_excel('vector0.xlsx')

# %%
import re

patterns = r'\w+\s*=\s*\d+'
line = """
    Some text =  more text
    Another line XYZ=2
    Third line DEF=3.14
"""

print(re.findall(patterns, line))
# Out:
# ['XYZ=2', 'DEF=3']

# %%
from pycparser import c_parser, c_generator, c_ast
import pycparser
generator = c_generator.CGenerator()
parser = c_parser.CParser()

line = '<start>  while  (  !a )  <end>'
line = line[7:-5].lstrip().rstrip().lstrip('}').lstrip()

p_c = 0
flag = 0
cond_flag = 0
if_line = ''
for i in enumerate(line):
    if i[1] == '(':
        if flag == 0:
            flag = 1
        p_c+=1
    elif i[1] == ')':
        if flag == 1:
            if p_c == 1:
                cond_flag = 1
        p_c -= 1
    if cond_flag:
        while_line = (line[:i[0]+1])
        break

line =  'int main() { ' + while_line + ' {} return 0; }'
parent_node = parser.parse(line)
condition  = parent_node.children()[0][1].children()[1][1].children()[0][1].children()[0][1]
print(condition.children()[0][1])
z = value_search(condition, [], 0)
# z
# Out:
# ID(name='a'
#    )
